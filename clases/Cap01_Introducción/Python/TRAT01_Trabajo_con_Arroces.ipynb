# %% [markdown]
# # Carga de Imágen desde Dropbox

# %%
import os
import requests
import wget
url_imagen = "https://raw.githubusercontent.com/joseramoniglesias/Tratamiento_Senales/main/clases/Cap01_Introducci%C3%B3n/Matlab/onerice.bmp"
#wgetcomand = "https://raw.githubusercontent.com/joseramoniglesias/Tratamiento_Senales/main/clases/Cap01_Introducci%C3%B3n/Matlab/onerice.bmp"
#wgetcomand = "wget https://www.dropbox.com/s/tzay0ej8irleft4/onerice.bmp"
#os.system(wgetcomand)

# %%
nombre_local_imagen = "onerice.bmp" # El nombre con el que queremos guardarla
imagen = requests.get(url_imagen).content
with open(nombre_local_imagen, 'wb') as handler:
  handler.write(imagen)

# %% [markdown]
# # Importación de Librerías

# %%
import numpy as np
import cv2
from cv2 import imread
import matplotlib.pyplot as plt
#from google.colab.patches import cv2_imshow

# %% [markdown]
# # Lectura y Despliegue de Imagen

# %%
img = cv2.imread('onerice.bmp')
plt.axis('off')
plt.imshow(img)
plt.show()

# %% [markdown]
# # Función de cómo es la imagen

# %%
def howis(img):
  print('size = ',img.shape)
  print('max  = ',np.max(img))
  print('min  = ',np.min(img))

howis(img)
# Out:
# size =  (64, 64, 3)
# max  =  183
# min  =  59

# %% [markdown]
# # Selección del primer canal de la imagen

# %%
X = img[:,:,0]
howis(X)
plt.axis('off')
plt.imshow(X,cmap='gray')
plt.show()
# Out:
# size =  (64, 64)
# max  =  183
# min  =  59

# %% [markdown]
# # Función de Segmentación por Umbral

# %%
def segmenta(X,t):
  (N,M) = X.shape
  Y = np.zeros((N,M))
  area = 0
  for i in range(N):
    for j in range(M):
      if X[i,j] > t:
        Y[i,j] = 255
        area = area + 1
  print('area = ',area)
  return Y

# %% [markdown]
# # Segmentación

# %%
Y = segmenta(X,120)
plt.axis('off')
plt.imshow(Y,cmap='gray')
plt.show()
# Out:
# area =  597

# %% [markdown]
# # Un ejemplo más complejo

# %%
url_imagen = "https://raw.githubusercontent.com/joseramoniglesias/Tratamiento_Senales/main/clases/Cap01_Introducci%C3%B3n/Matlab/rice.png"
#wgetcomand = "https://raw.githubusercontent.com/joseramoniglesias/Tratamiento_Senales/main/clases/Cap01_Introducci%C3%B3n/Matlab/rice.png"
#wgetcomand = "wget https://www.dropbox.com/s/n81hldnrcb07muh/rice.png"
#os.system(wgetcomand)

# %%
nombre_local_imagen = "rice.png" # El nombre con el que queremos guardarla
imagen = requests.get(url_imagen).content
with open(nombre_local_imagen, 'wb') as handler:
  handler.write(imagen)

# %%
img = cv2.imread('rice.png')
X   = img[:,:,0]
howis(X)
plt.axis('off')
plt.imshow(X,cmap='gray')
# Out:
# size =  (512, 512)
# max  =  207
# min  =  38

# %%
Y = segmenta(X,120)
plt.axis('off')
plt.imshow(Y,cmap='gray')
# Out:
# area =  76112

# %% [markdown]
# # Definición de imagen con fondo homogéneo

# %%
(N,M) = X.shape
Xm    = np.zeros((N,M),np.uint8)
for i in range(N):
  xmin = np.min(X[i,:])
  Xm[i,:] = X[i,:] - xmin
plt.axis('off')
plt.imshow(Xm,cmap='gray')

# %%
Y = segmenta(Xm,60)
plt.axis('off')
plt.imshow(Y,cmap='gray')
# Out:
# area =  68445

# %% [markdown]
# **Copyright**
#
# The notebooks are provided as [Open Educational Resource](https://de.wikipedia.org/wiki/Open_Educational_Resources). Feel free to use the notebooks for your own educational purposes. The text is licensed under [Creative Commons Attribution 4.0](https://creativecommons.org/licenses/by/4.0/), the code of the IPython examples under the [MIT license](https://opensource.org/licenses/MIT).
