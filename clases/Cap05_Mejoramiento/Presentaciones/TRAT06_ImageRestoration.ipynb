# %% [markdown]
# # Procesamiento de Imágenes: Restauración de Imágenes
#
# José Ramón Iglesias. Departamento Electrónica ,Facultad de Ingeniería, Universidad Popular del Cesar
#
#
#
#
#
# ---
#
# Este ejemplo es parte del curso [Tratamiento de Señales]
# ---
#
#
#
#
#
#
# ---

# %% [markdown]
# # Imagenes usadas en este ejemplo
#
# Imágenes originals:
#
#
# 1.   Santiago: https://flic.kr/p/VD2Pin
# 2.   Puerta: https://flic.kr/p/dmx5iU

# %%
# !wget https://www.dropbox.com/s/y1nyflpmh0y1w8j/santiago.png
# !wget https://www.dropbox.com/s/t8wjw4uv6a1qs3o/puerta_bw.png
# !wget https://www.dropbox.com/s/va5la1i5neqcnlr/santiago512.png
# Out:
# --2020-11-07 20:14:44--  https://www.dropbox.com/s/y1nyflpmh0y1w8j/santiago.png
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.5.1, 2620:100:601d:1::a27d:501
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.5.1|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: /s/raw/y1nyflpmh0y1w8j/santiago.png [following]
# --2020-11-07 20:14:44--  https://www.dropbox.com/s/raw/y1nyflpmh0y1w8j/santiago.png
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://ucc79ef241606a1e0d049509630a.dl.dropboxusercontent.com/cd/0/inline/BCwZsyz9seI1cbGR-qpmZcrYvPxNGaFtfgEBQw-ZKfstr1FGKqtcl5FEemUpkm7Gtjw1wTUsRTH6_DhsLZiHlBsHGQuHcJlKX106zPYm8GoKv1QOFo2uMhi5ZPvHzl6tuaY/file# [following]
# --2020-11-07 20:14:45--  https://ucc79ef241606a1e0d049509630a.dl.dropboxusercontent.com/cd/0/inline/BCwZsyz9seI1cbGR-qpmZcrYvPxNGaFtfgEBQw-ZKfstr1FGKqtcl5FEemUpkm7Gtjw1wTUsRTH6_DhsLZiHlBsHGQuHcJlKX106zPYm8GoKv1QOFo2uMhi5ZPvHzl6tuaY/file
# Resolving ucc79ef241606a1e0d049509630a.dl.dropboxusercontent.com (ucc79ef241606a1e0d049509630a.dl.dropboxusercontent.com)... 162.125.9.15, 2620:100:601d:15::a27d:50f
# Connecting to ucc79ef241606a1e0d049509630a.dl.dropboxusercontent.com (ucc79ef241606a1e0d049509630a.dl.dropboxusercontent.com)|162.125.9.15|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 639161 (624K) [image/png]
# Saving to: ‘santiago.png’
#
# santiago.png        100%[===================>] 624.18K  --.-KB/s    in 0.09s
#
# 2020-11-07 20:14:45 (6.69 MB/s) - ‘santiago.png’ saved [639161/639161]
#
# --2020-11-07 20:14:45--  https://www.dropbox.com/s/t8wjw4uv6a1qs3o/puerta_bw.png
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.5.1, 2620:100:601d:1::a27d:501
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.5.1|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: /s/raw/t8wjw4uv6a1qs3o/puerta_bw.png [following]
# --2020-11-07 20:14:46--  https://www.dropbox.com/s/raw/t8wjw4uv6a1qs3o/puerta_bw.png
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://uc6fcae9761bbba505d0ccb95a42.dl.dropboxusercontent.com/cd/0/inline/BCwWOY6nnNTCJWWquI-ZlXDSgcf4isQ33EkkQpPwZWUF7ckgkrslBQmUF0B1WNunHhIo2x-hC6XGOf3q7aDBDc68TCRE37ZNcqe4n3nFdeLCNg3Rh3OKIkuNbVlBkPE0yrQ/file# [following]
# --2020-11-07 20:14:46--  https://uc6fcae9761bbba505d0ccb95a42.dl.dropboxusercontent.com/cd/0/inline/BCwWOY6nnNTCJWWquI-ZlXDSgcf4isQ33EkkQpPwZWUF7ckgkrslBQmUF0B1WNunHhIo2x-hC6XGOf3q7aDBDc68TCRE37ZNcqe4n3nFdeLCNg3Rh3OKIkuNbVlBkPE0yrQ/file
# Resolving uc6fcae9761bbba505d0ccb95a42.dl.dropboxusercontent.com (uc6fcae9761bbba505d0ccb95a42.dl.dropboxusercontent.com)... 162.125.9.15, 2620:100:601d:15::a27d:50f
# Connecting to uc6fcae9761bbba505d0ccb95a42.dl.dropboxusercontent.com (uc6fcae9761bbba505d0ccb95a42.dl.dropboxusercontent.com)|162.125.9.15|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 241446 (236K) [image/png]
# Saving to: ‘puerta_bw.png’
#
# puerta_bw.png       100%[===================>] 235.79K  --.-KB/s    in 0.07s
#
# 2020-11-07 20:14:46 (3.52 MB/s) - ‘puerta_bw.png’ saved [241446/241446]
#
# --2020-11-07 20:14:47--  https://www.dropbox.com/s/va5la1i5neqcnlr/santiago512.png
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.5.1, 2620:100:601d:1::a27d:501
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.5.1|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: /s/raw/va5la1i5neqcnlr/santiago512.png [following]
# --2020-11-07 20:14:47--  https://www.dropbox.com/s/raw/va5la1i5neqcnlr/santiago512.png
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://ucb128040a00ee07544f45aba63d.dl.dropboxusercontent.com/cd/0/inline/BCxof2Mj4zG16qPE9wqaJC7W6iDP2z-49oF7dIfzYXOHA-6qOLte0CcI584p0FpQZ9AJ6icHqT8wAhjrIvjwgzC-61pK2PhJP82vRfi36pnBUPod8gZ4O_mi_20i_0KrvHU/file# [following]
# --2020-11-07 20:14:47--  https://ucb128040a00ee07544f45aba63d.dl.dropboxusercontent.com/cd/0/inline/BCxof2Mj4zG16qPE9wqaJC7W6iDP2z-49oF7dIfzYXOHA-6qOLte0CcI584p0FpQZ9AJ6icHqT8wAhjrIvjwgzC-61pK2PhJP82vRfi36pnBUPod8gZ4O_mi_20i_0KrvHU/file
# Resolving ucb128040a00ee07544f45aba63d.dl.dropboxusercontent.com (ucb128040a00ee07544f45aba63d.dl.dropboxusercontent.com)... 162.125.9.15, 2620:100:601d:15::a27d:50f
# Connecting to ucb128040a00ee07544f45aba63d.dl.dropboxusercontent.com (ucb128040a00ee07544f45aba63d.dl.dropboxusercontent.com)|162.125.9.15|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 156294 (153K) [image/png]
# Saving to: ‘santiago512.png’
#
# santiago512.png     100%[===================>] 152.63K  --.-KB/s    in 0.05s
#
# 2020-11-07 20:14:48 (2.80 MB/s) - ‘santiago512.png’ saved [156294/156294]

# %% [markdown]
# # Ejemplo de Restauración de Imágenes
#
# En este ejemplo:
#
#
#
# *   $\bf F$: Imagen original
# *   $\bf G$: Imagen degradada
# *   $\bf \hat F$: Imagen restuarada
#
# El proceso de degradación consiste en un movimiento uniforme horizontal de $n$ pixeles, donde cada fila es modelada como:
#
# $
# \left[ \begin{array}{c c c c c c c}
# h_1 & ... & h_n & 0   & 0   & 0   & 0   \\
# 0   & h_1 & ... & h_n & 0   & 0   & 0   \\
#     &  :  &     &     & :   &     &     \\
# 0   &  0  &  ...& 0 & h_1 & ... & h_n
# \end{array} \right]
# \left[ \begin{array}{c}
# f_1 \\
# f_2 \\
# :   \\
# f_M
# \end{array}
# \right]
# =
# \left[ \begin{array}{c}
# g_1 \\
# g_2 \\
# :   \\
# g_N
# \end{array}
# \right]
# $

# %% [markdown]
# ## Algoritmo de restauración
#
# La solución a este problema, se obtiene minimizando la siguiente función objetivo que usa multiplicadores de Lagrange:
#
# $
# V({\bf f}) = \lambda\parallel{\bf H}{\bf f}-{\bf g}\parallel^2 +\parallel{\bf  W}{\bf  f}\parallel^2
# $
#
# donde $\bf W$ es un regulador que reduce el rizado de ${\bf f}$. Derivando $V$ con respecto a ${\bf f}$ e igualando a cero se obtiene:
#
# $
# {\bf \hat f} = \lambda \left[ \lambda {\bf H}^{\sf T} {\bf H} + {\bf W}^{\sf T} {\bf W} \right]^{-1} {\bf H} ^{\sf T} {\bf g}.
# $
#
# En este ejemplo usamos ${\bf W} = {\bf I}$, sin embargo se puede usar otras matrices de regularización. En la práctica $\lambda = 10^{-6}$ obtiene buenos resultados.

# %% [markdown]
# Para criterio MINIO:
#
# Computer Vision for X-ray Testing. Springer. 2nd Edition.

# %% [markdown]
# ![Screen Shot 2020-10-27 at 2.35.30 pm.png](data:image/png;base64,...)

# %%
def res_minio(_img_g, h, method='minio'):
    """

    Args:
        _img_g: blured image as ndarray.
        h: PSF as ndarray.
        method: integer value to select minimization method:
                'minio': ||f_n - g|| -> min
                'other': ||f|| -> min

    Returns:
        _img_f: the restored image as ndarray.
    
    Raises:
        ValueError: if h is not ndarray.
        Exception

    Authors:
        Christian Pieringer & Domingo Mery
        from pyxvis library.
    """

    _valid_methods = ['minio', 'eye']

    # Check input parameters
    # Input image _img_g
    if not isinstance(_img_g, np.ndarray):
        raise Exception('{} is not valid input format for the blured image _img_g.'.format(type(_img_g)))

    # PSF h
    if not isinstance(h, np.ndarray):
        raise Exception('{} is not a valid format for PSF.'.format(type(h)))

    # Method
    if method not in _valid_methods:
        raise ValueError('method do not meet {} as a valid method'.format(method))

    # Main
    nh = h.shape[-1]
    n = _img_g.shape[-1]
    m = n + nh - 1
    _mat_h = np.zeros((n, m))

    # Composing H matrix
    for i in range(n):
        _mat_h[i, i:i + nh] = h.ravel()

    _lambda = 1e6  # Lagrange multiplier

    if method == 'minio':
        _mat_p = np.hstack([np.eye(n, dtype='float'), np.zeros((n, nh - 1))])
        _img_f = _img_g @ (_lambda * _mat_h + _mat_p)
        _img_f = _img_f @ (np.linalg.inv((_lambda * _mat_h).T @ _mat_h + _mat_p.T @ _mat_p)).T
    
    if method =='eye':
        _img_f = _img_g @ _mat_h
        _img_f = _img_f @ (np.linalg.inv((_lambda * _mat_h).T @ _mat_h + np.eye(m, dtype='float'))).T

    # Clip the image between 0 and 255
    _img_f[_img_f < 0] = 0
    _img_f[_img_f > 255] = 255

    return _img_f

# %% [markdown]
# ## Ejemplo de movimiento horizontal

# %%
import numpy as np
import matplotlib.pylab as plt
from cv2 import imread, filter2D, IMREAD_GRAYSCALE, CV_64F

img = imread('santiago512.png', IMREAD_GRAYSCALE)

n = 40
h = np.ones((1, n)) / n

N = img.shape[0]
M = N-n+1

img_g = filter2D(img.astype('double'), CV_64F, h)
img_g = img_g[:,0:M]
fs = res_minio(img_g, h, method='eye')

fig, ax = plt.subplots(3, 1, figsize=(48, 34))
ax[0].imshow(img, cmap='gray')
ax[0].set_title('Original image')
ax[0].axis('on')
ax[1].imshow(img_g, cmap='gray')
ax[1].set_title('Degraded image')
ax[1].axis('on')
ax[2].imshow(fs, cmap='gray')
ax[2].set_title('Restored image')
ax[2].axis('on')
plt.show()

# %%
print(fs.shape)
# Out:
# (512, 512)
